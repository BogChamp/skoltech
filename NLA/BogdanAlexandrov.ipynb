# %% [markdown]
# # Problem Set 1 (61 points)

# %% [markdown]
# ## Important information
# 1.  We provide signatures of the functions that you have to implement. Make sure you follow the signatures defined, otherwise your coding solutions will not be graded.
#
# 2.  Please submit the single Jupyter Notebook file, where only Python and Markdown/$\\LaTeX$ are used. Any hand-written solutions inserted by photos or in any other way **are prohibitive and will not be graded**. If you will have any questions about using Markdown, ask them!
# 3.  The works will be checked for **plagiarism**. The score will be divided by the number of similar works.

# %% [markdown]
# # Problem 1 (18 pts)

# %% [markdown]
# ### Problem 1.0 (Matrix norms) (8 pts)
#
# 1. For any norm $\|\cdot\|$ in finite dimentional space $\mathbb{C}^{N}$ we define dual norm $\|x\|^{'} = \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\}$, where ${\cdot}^{\star}$ denotes transpose complex-conjugate vector.
#
# + (2 pts). Prove that $\|\cdot\|^{'}$ is a norm.\
#   Let's check if $\|x\|^{'}$ satisfies norm properties.\
#   1)Modulus of number is nonnegative, so it leads to $|y^{\star} x| \geq 0 \to \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\} \geq 0 \to \|x\|^{'} \geq 0$.\
#   And also we know, that $|a| = 0$ iff $a = 0$. $\|y\|=1$, so $y \neq 0$ and it leads to $\sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\} = 0 \to |y^{\star} x|=0\ \forall y:\|y\|=1 \to y^{\star} x\ \forall y:\|y\|=1  = 0 \to x = 0$
#
#   2)$\|\alpha x\|^{'} = \sup\left\{\left|y^{\star} \alpha x\right|:\left\|y\right\|=1\right\} = \sup\left\{\left|\alpha||y^{\star} x\right|:\left\|y\right\|=1\right\} = |\alpha| \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\} = |\alpha| \|x\|^{'}$
#
#   3)$\|x+z\|^{'} = \sup\left\{\left|y^{\star} (x+z)\right|:\left\|y\right\|=1\right\} = \sup\left\{\left|y^{\star}x+y^{\star}z)\right|:\left\|y\right\|=1\right\}$.\
#   Because of modulus property $|x+y| \leq |x| + |y|$ we get $|y^{\star}x+y^{\star}z| \leq |y^{\star}x| + |y^{\star}z| \to \sup\left\{\left|y^{\star}x+y^{\star}z\right|:\left\|y\right\|=1\right\} \leq \sup\left\{\left|y^{\star}x|+|y^{\star}z\right|:\left\|y\right\|=1\right\} \leq \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|=1\right\} + \sup\left\{\left|y^{\star} z\right|:\left\|y\right\|=1\right\} = \|x\|^{'} + \|z\|^{'}$ Thus $\|x+z\|^{'} \leq \|x\|^{'} + \|z\|^{'}$
#
# + (2 pts). Find dual norms for Chebyshev norm $\left\|x\right\|_{\infty} = \max\limits_{i=1,\dots, N}|x_{i}|$ and $l_1$ norm $\left\|x\right\|_1 = \sum\limits_{i=1}^{N}|x_{i}|$.\
# 1)First, let's find dual norm for Chebyshev norm.\
# $\|x\|_{\infty}^{'} = \sup\left\{\left|y^{\star} x\right|:\left\|y\right\|_{\infty}=1\right\}$. $|y^{\star} x| = |\sum\limits_{i=1}^{N}y_i^{\star}x_i| \leq \sum_{i=1}^N|y_i^{\star}x_i| = \sum_{i=1}^N|y_i^{\star}||x_i| \leq \sum_{i=1}^N\max_i(|y_i^{\star}|)|x_i| = \max_i(|y_i^{\star}|) \sum_{i=1}^N|x_i| = \|y\|_{\infty}\sum_{i=1}^N|x_i| = \|y\|_{\infty}\|x\|_1 = \|x\|_1$ because $|y^{\star}| = |y|$.\
# So, $\sup\left\{\left|y^{\star} x\right|:\left\|y\right\|_{\infty}=1\right\} \leq \sup\left\{\|x\|_1:\left\|y\right\|_{\infty}=1\right\} = \|x\|_1$. Now let's show, that's there exisis $y$ such this unequlity turns to equality. Let's check such $y$ thats $y_i = x_i / |x_i|$. Obviously, $\|y\|_{\infty} = 1$. And $|y^{\star} x| = |\sum\limits_{i=1}^{N} y_i^{\star} x_i| = |\sum\limits_{i=1}^{N} |x_i|^2 / |x_i|| = |\sum\limits_{i=1}^{N} |x_i|| = \sum\limits_{i=1}^{N} |x_i| = \|x\|_1$.
# Thus, $\|x\|_{\infty}^{'} = \|x\|_1$\
# 2) Now find for l1 norm.\
# $|y^{\star} x| = |\sum\limits_{i=1}^{N}y_i^{\star}x_i| \leq \sum\limits_{i=1}^{N}|y_i^{\star}x_i| = \sum\limits_{i=1}^{N}|y_i^{\star}||x_i|  \leq \sum\limits_{i=1}^{N}|y_i^{\star}|\max_i(|x_i|) = \max_i(|x_i|) \sum\limits_{i=1}^{N}|y_i^{\star}| = \|x\|_{\infty} \|y^{\star}\|_1 = \|x\|_{\infty} \|y\|_1 = \|x\|_{\infty}$.\
# So, $\sup\left\{\left|y^{\star} x\right|:\left\|y\right\|_1=1\right\} \leq \sup\left\{\|x\|_{\infty}:\left\|y\right\|_1=1\right\} = \|x\|_{\infty}$.\
# If we will take such vector $y$ that it has 0 on all positions except such $i$, that $|x_i| = max_k |x_k|$, this y will satisfy condition $\|y\|_1 = 1$ and $|y^{\star} x| = |\max\limits_{k=1,\dots, N} |x_k|| = \max\limits_{k=1,\dots, N} |x_k| = \|x\|_{\infty}$.\
# And thus $\|x\|_1^{'} = \|x\|_{\infty}$
#
# + (2 pts). Find dual norm for $l_p$ norm $\left\|x\right\|_{p} = \left(\sum\limits_{i=1}^{N}|x_{i}|^{p}\right)^{1/p}$.\
# $|y^{\star}x| = |\sum\limits_{i=1}^{N}y_i^{\star}x_i| \leq \sum\limits_{i=1}^{N}|y_i^{\star}x_i|$.
# Let's use Hölder's inequality. Then:\
# $\sum\limits_{i=1}^{N}|y_i^{\star}x_i| \leq (\sum\limits_{i=1}^{N}|y_i^{\star}|^p)^{1/p}(\sum\limits_{i=1}^{N}|x_i|^q)^{1/q}$ where $1/p + 1/q = 1 \to q = p/(p-1)$ and $p,q \geq 0$.\
# So $|y^{\star}x| \leq (\sum\limits_{i=1}^{N}|y_i^{\star}|^p)^{1/p}(\sum\limits_{i=1}^{N}|x_i|^q)^{1/q} = (\sum\limits_{i=1}^{N}|x_i|^q)^{1/q} = \|x\|_q = \|x\|_{p/(p-1)}$, due to $\|y\|_p = 1$\
# $\sup\left\{\left|y^{\star} x\right|:\left\|y\right\|_p=1\right\} \leq \sup\left\{\|x\|_{p/(p-1)}:\left\|y\right\|_p=1\right\} = \|x\|_{p/(p-1)}$\
# Let's check $y$ such $y=z/\|z\|_p$, where z:$z_i = \frac{x_i}{|x_i|}|x_i|^{q-1}$. Then $\|z\|_p = (\sum\limits_{i=1}^{N}|z_i|^p)^{1/p} = (\sum\limits_{i=1}^{N}|\frac{x_i}{|x_i|}|x_i|^{q-1}|^p)^{1/p} = (\sum\limits_{i=1}^{N}|x_i|^{p(q-1)})^{1/p} = (\sum\limits_{i=1}^{N}|x_i|^{q})^{1/p} = \|x\|_q^{q/p}$
#
#   $|y^{\star}x| = |\sum\limits_{i=1}^{N}y_i^{\star}x_i| = |\sum\limits_{i=1}^{N}\frac{x_i}{|x_i|}\frac{|x_i|^{q-1}}{\|x\|_q^{q/p}} x_i| = |\sum\limits_{i=1}^{N}|x_i|^{q}|/\|x\|_q^{q/p}| = \frac{\|x\|_q^q}{\|x\|_q^{q/p}} = \|x\|_q = \|x\|_{p/(p-1)}$\
# So, $\|x\|_p^{'}=\|x\|_{p/(p-1)}$
# + (2 pts). Find dual norm for weighted norm $\left\|x\right\|_{A} = \left(x^T A x\right)^{1/2}$ with positive-definite matrix $A$ and $x\in\mathbb{R}^{N}$.\
# $\|x\|_A^{'} = \sup\left\{|y^T x|:\left\|y\right\|_A=1\right\}$.\
# We know that $\|y\|_A = \left(y^T A y\right)^{1/2} = 1 \to y^T A y=1$. And also $1=1^T=((y^T A y)^T)^{1/2} = (y^T A^T y)^{1/2}$. So we can rewrite $y^T A y = 1$ as $y^T(A+A^T)y/2 = 1$. Let's name $B = \frac{A+A^T}{2}$. Because B - symmetric, we can use Cholesky decomposition, so $B = LL^T$. And $\|y\|_A=1 \iff \|y\|_B = 1 \iff \|L^Ty\|_2=1$\
# Let be $z = L^Ty \to y = L^{-T}z$. Then:\
# $\|x\|_A^{'} = \sup\left\{|y^T x|:\left\|y\right\|_A=1\right\} = \sup\left\{|y^T x|:\|L^Ty\|_2 = 1\right\} = \sup\left\{|(L^{-T}z)^T x|:\|z\|_2 = 1\right\}=\sup\left\{|z^T L^{-1}x|:\|z\|_2 = 1\right\} \leq \sup\left\{\|z\|_2 \|L^{-1}x\|_2:\|z\|_2 = 1\right\} = \|L^{-1}x\|_2 = ((L^{-1}x)^TL^{-1}x)^{1/2} = (x^TL^{-T}L^{-1}x)^{1/2} = (x^T(LL^{T})^{-1}x)^{1/2} = \|x^TB^{-1}x\|_2 = \|x\|_{B^{-1}}$ = $\|x\|_{2(A+A^T)^{-1}}$. Here inequality appears due to Cauchy inequality. $(A+A^T)$ is invertible due to it's positive-definitness and thus all its eigenvalues greater than 0 so determinant not equal to zero. \
# Inequality turns to quality if we take $y = \frac{L^{-T}L^{-1}x}{\|L^{-1}x\|_2} = \frac{B^{-1}x}{\|L^{-1}x\|_2}$ and also it satisfies $\|y\|_B = 1 \to \|y\|_A=1$.\
# So $\|x\|_A^{'} = \|x\|_{2(A+A^T)^{-1}}$

# %% [markdown]
# ### Problem 1.1 (Matrix norms) (10 pts)
#
# 1. Let $U \in \mathbb{R}^{n \times r}$ be an $n \times r$ matrix with orthonormal columns $U^{\top} U = I_r$. Let $V$ be an $m \times r$ matrix.
#
# + (2 pts). Propose an algorithm for the computation of $\Vert A \Vert^2_F$, where $A = U V^{\top}$, and estimate its complexity with respect to $n, m, r$. How orthogonalization can be used?
#
# $\|A\|_F^2=\|UV^T\|_F^2=\|V^T\|_F^2=\|V\|_F^2$ due to orthonormality of U matrix.\
# So we can compute norm of $A$ as $\sum\limits_{i=1}^{n}\sum\limits_{j=1}^{m}|a_{ij}|^2 = \|A\|_F^2 = trace(V^TV) = \sum\limits_{i=1}^{m}\sum\limits_{j=1}^{r}|v_{ij}|^2$\
# Let's estimate complexity. Both multiplication and add cmplexity is $O(mr)$ because V has m rows with r element in each of them.
# + (3 pts). Consider the matrix $B = A \circ A$, where $\circ$ is the elementwise product of matrices (i.e., the elements of the matrix $B$ are squares of the elements of the matrix $A$). What is the maximal possible rank of the matrix $B$?
#
# Let's prove that for every matricies $A,B$ holds $rank(A\circ B)\leq rank(A)rank(B)$.\
# Let's look at SVD for $A$ and $B$. $A=U_A\Sigma_AV_A^{\star}$, $B=U_B\Sigma_BV_B^{\star}$. So we can write $A$ as $A=\sum\limits_{i=1}^{rankA}\sigma_{i_A}u_{i_A}v_{i_A}^{\star}$. And thus elementwise product of matricies can be shown as $A \circ B = \sum\limits_{j=1}^{rankB}\sum\limits_{i=1}^{rankA}\sigma_{i_A}\sigma_{j_B}(u_{i_A}\circ u_{j_B})(v_{i_A}\circ v_{j_B})^{\star}$ because of $u_{i_A}v_{i_A}^{\star} \circ u_{i_B}v_{i_B}^{\star}= (u_{i_A}\circ u_{j_B})(v_{i_A}\circ v_{j_B})^{\star}$ and for every matricies X,Y and Z holds $X\circ (Y+Z) = X\circ Y + X \circ Z$\
# Thus, $A\circ B$ is a sum of $rankA * rankB$ 1-rank matrices, so $rank(A\circ B)$ cannot be bigger than $rankA * rankB$.
# So, $A\circ A = \sum\limits_{j=1}^{rankA}\sum\limits_{i=1}^{rankA}\sigma_{i}\sigma_{j}(u_{i}\circ u_{j})(v_{i}\circ v_{j})^{\star}$.(Here vectors $v_j$ and columns of matrix V of A=UV decomposition not the same)\
# Due to proven statement, $rank(B) \leq (rankA)^2$. But let's notice, that matricies $(u_{i}\circ u_{j})(v_{i}\circ v_{j})^{\star}$ and $(u_{j}\circ u_{i})(v_{j}\circ v_{i})^{\star}$ in the $A \circ A$ sum are equal. So, there are $\frac{rank(A)(rank(A)+1)}{2}$ different matricies. Thus, $rank(B) \leq min(\frac{rank(A)(rank(A)+1)}{2}, r, m, n)$
# + (5 pts). Propose an algorithm for the computation of $\Vert B \Vert^2_F$ and estimate its complexity with respect to $n, m, r$.\
# Let's assume, that $n \leq m \leq r$.
# We have such matrix A that $A=UV=\sum\limits_{i=0}^ru_iv_i^T$. It's Hadamard square is equal to $A\circ A = \sum\limits_{i=0}^r\sum\limits_{j=0}^r(u_i\circ u_j)(v_i \circ v_j)^T$. Now let's find frobenius norm of B:
# $$\|B\|_F^2=trace((A\circ A)^T(A \circ A)) = trace((\sum\limits_{i=0}^r\sum\limits_{j=0}^r(u_i\circ u_j)(v_i \circ v_j)^T)^T(\sum\limits_{k=0}^r\sum\limits_{l=0}^r(u_k\circ u_l)(v_k \circ v_l)^T)) =  trace((\sum\limits_{i=0}^r\sum\limits_{j=0}^r(v_i \circ v_j)(u_i\circ u_j)^T)(\sum\limits_{k=0}^r\sum\limits_{l=0}^r(u_k\circ u_l)(v_k \circ v_l)^T)) = trace(\sum\limits_{i=0}^r\sum\limits_{j=0}^r\sum\limits_{k=0}^r\sum\limits_{l=0}^r(v_i \circ v_j)(u_i\circ u_j)^T(u_k\circ u_l)(v_k \circ v_l)^T)$$
# We know that inner product $(u_i\circ u_j)^T(u_k\circ u_l)$ is a number, and $trace(A+B)=trace(A)=trace(B)$. Thus we have:
# $$trace(\sum\limits_{i=0}^r\sum\limits_{j=0}^r\sum\limits_{k=0}^r\sum\limits_{l=0}^r(v_i \circ v_j)(u_i\circ u_j)^T(u_k\circ u_l)(v_k \circ v_l)^T) = \sum\limits_{i=0}^r\sum\limits_{j=0}^r\sum\limits_{k=0}^r\sum\limits_{l=0}^rtrace((v_i \circ v_j)(u_i\circ u_j)^T(u_k\circ u_l)(v_k \circ v_l)^T)=\sum\limits_{i=0}^r\sum\limits_{j=0}^r\sum\limits_{k=0}^r\sum\limits_{l=0}^r (u_i\circ u_j)^T(u_k\circ u_l)trace((v_i \circ v_j)(v_k \circ v_l)^T)$$
# So to find $u_i \circ u_j$ we need n multiplications, hence to find $(u_i\circ u_j)^T(u_k\circ u_l)$ O(n) operations needed. To find $v_i \circ v_j$ we need m multiplications, so to find $trace((v_i \circ v_j)(v_k \circ v_l)^T)$ we need O(m) operations, because there are m diagonal elements and every diagonal element can be found as $a_{xy}=(v_i \circ v_j)_x*(v_k \circ v_l)_y$ for O(1) operations. Thus overall complexity is O((n+m)r^4)=O(nr^4) because $n\geq m$.

# %% [markdown]
# ## Problem 1.2 (Unitary and orthogonal matrices) (4 pts)
#
# + (2 pts). Let $O\in\mathbb{R}^{n\times n}$ be orthogonal matrix. Characterise explicitly all orthogonal matrices that are positive definite. You may start with $n=2$.\
# Let's look at $O = \begin{pmatrix}
# a & b\\
# c & d
# \end{pmatrix}$. Since it is orthogonal and thus $Q^TQ=QQ^T=I$, we get system
# $\begin{cases}
#       a^2+b^2=1\\
#       c^2+d^2=1\\
#       ac+bd=0\\
#       a^2+c^2=1\\
#       b^2+d^2=1\\
#       ab+cd=0
# \end{cases}$\
# Hence, $|a|=|d|, |b|=|c|$. Solution of system can be represented as $a=d=\cos\alpha, c=-b=\sin\alpha$ for some $\alpha$.\
# O is positive-definite thus $\forall x:x^TOx > 0 \to ax_1^2+cx_1x_2+bx_1x_2+dx_2^2=a(x_1^2+x_2^2)>0$.So a should be greater than 0. And thus $\cos\alpha > 0 \to \alpha \in (-\pi/2;\pi/2)$. So $O = \begin{pmatrix}
# \cos\alpha & -\sin\alpha \\
# \sin\alpha & \cos\alpha
# \end{pmatrix}$, where $\alpha \in (-\pi/2;\pi/2)$.\
# So, it is a matrix of rotation - Jacobi matrix. And it rotates coordinates at an angle of no more than 90 degrees.\
# Now let's see what about n > 2. We know that every orthogonal matrix can be brought to canonical form $O_c$, where $O_c = \begin{pmatrix}
# I_r & 0 & 0 & \ldots & 0\\
# 0 & -I_m & 0 & \ldots & 0\\
# 0 & 0 & R_{\phi_1} & \ldots & 0\\
# 0 & 0 & 0 & \ldots & R_{\phi_k}
# \end{pmatrix}$. Here $I_r$ - unit matrix of size r, $I_m$ - unit matrix of size m, $R_{\alpha} = \begin{pmatrix}
# \cos\alpha & -\sin\alpha \\
# \sin\alpha & \cos\alpha
# \end{pmatrix}$ - rotation matrix at angle $\alpha$. Here $r+m+2*k=n$- size of matrix.\
# O must be positive definite, thus its canonical form shouldn't contain -1 on diagonal, otherwise we can take such vector $v=(0,\ldots,1,\ldots,0)^T$, where position of 1 is equal to position of -1 on diagonal of matrix $O_c$, and it leads to: $v^TQ_cv = -1 < 0$. So canonical form of O has no -1 on diagonal.\
#
#   Now, let's learn, what kind of $R_{\phi_i}$ are allowed for positive definite matrix O. As for matrix n=2, angle of rotation should be $\phi_i \in (-\pi/2;\pi/2)$, otherwise there are such vector $v=(0,\ldots,x_i,\ldots,0)$ that $v^TO_cv=\cos\phi_i x_i^2 \leq 0$. We described canonical form of orthogonal positive definite matrices - there canonical forms should be positive definite.\
#   Since $O_c$ is canonical form of O, than $O = PO_cP^T$. And as we can see, $\forall v \neq 0 \to v^TOv=v^TPO_cP^Tv=(P^Tv)^TO_cP^Tv > 0$ due to $O_c$ positive definite matrix. And thus O is positive definite matrix.\
#   So, all positive definite orthogonal matrices should have positive definite canonical forms, which don't do any reflections, only rotations along some pairs of axis at angle no more than $90^{\circ}$. And if you want generate such matrix, first create some matrix $O_c = \begin{pmatrix}
# I_r  & 0 & \ldots & 0\\
# 0  & R_{\phi_1} & \ldots & 0\\
# 0 & 0 & \ldots & R_{\phi_k}
# \end{pmatrix}$ with $\phi_i \in (-\pi/2;\pi/2)$, and then take any orthogonal transformations P and get any orthogonal positive definite matrix $PO_cP^T$.
#
# + (2 pts). Show that any unitary matrix from $\mathbb{C}^{n\times n}$ can be represented as a product of at most $n$ Householder reflectors.\
# We have some unitary matrix $U \in \mathbb{C}^{n\times n}$. Let's apply Housholder algorithm for this matrix. First Housholder matrix $H_1$ will transform first column of $U$ to $(u_{11}^{'}, 0,0,\ldots,0)$. Second H_2 matrix will transform second column of $H_1U$ to $(u_{12}^{'}, u_{22}^{'}, 0,\ldots 0)$ and so on. In the end we will have $$H_1H_2\ldots H_{n-1}U=R$$, where R is upper triangular matrix.\
# Since all matricies $H_{i},i\in[1\ldots n-1]$ and U are unitary then R should be also unitary. It is noticeable, that orthogonal upper triangular matrix will be diagonal. Because $R^TR=I\to$ first diagonal element square equal to 1. And all multiplications $r_{11}*r_{1j}=0\ \forall j \in [2\ldots n]$, so $r_{1j}=0\ \forall j \in [2\ldots n]$ due to $r_{11}\neq0$. Using this conclusions for all rows of $R$ we will get that only diagonal elements nonzeros. Moreover, this elemenst $r_{ii}\in\{-1,1\}$ because there squares equal to 1.\
# This matrix R is Housholder matrix too, because it reflects vectors in those coordinates $x_i$ where $r_{ii}=-1$, and preserves other vector elements.\
# Thus, $U$ can be shown as $U=H_{n-1}^{\star}\ldots H_2^{\star}H_1^{\star}R$(due to $H_i$ are Housholder and thus unitary), where $H_i$ and $R$ are Housholder matricies(or reflectors), and there number is n.

# %% [markdown]
# # Problem 2 (15 pts)
#
# 1. We define approximate $\epsilon-$rank of matrix $A$ as $\text{rank}_{\epsilon}A = \min \left\{\text{rank}(X): \left\|A-X\right\|_{\max}\leq \epsilon\right\}$.
#
#
# + (6 pts). Let $f(x, y),\,x,y\in[0, 1]$ is analytic function with $\left|\partial_y^{(k)}f(x, y)\right|_{y=0}\leq M$ for all $k$. Show that approximate rank of matrix $A_{ij} = f(x_i, y_j)$ where $x_{i},\,i=1,\dots,p$, $y_{j},\,j=1,\dots,q$ are arbitrary points inside $[0, 1]^2$, is bounded independent of $p$, $q$ and the choice of points.
#
# Function f is analytic, so it differentiable any $k>0$ times and can be represented as a Tailor series in any point of domain definition.
# We have boundary condition only on $y$, so let's look at function at points $x_i,y_j$ like a Taylor series with respect to y in 0 variable:$$\sum\limits_{i=0}^{\infty}\frac{\partial^i f(x_i,0)}{\partial y^i}\frac{y_j^i}{i!}$$
# Thus, whole matrix A can be represented as:
# $$\begin{pmatrix}
# \sum\limits_{n=0}^{\infty}\frac{\partial^n f(x_1,0)}{\partial y^n}\frac{y_1^n}{n!} & \sum\limits_{n=0}^{\infty}\frac{\partial^n f(x_1,0)}{\partial y^n}\frac{y_2^n}{n!} & \ldots & \sum\limits_{n=0}^{\infty}\frac{\partial^n f(x_1,0)}{\partial y^n}\frac{y_q^n}{n!}\\
# \ldots & \ldots\\
# \sum\limits_{n=0}^{\infty}\frac{\partial^n f(x_p,0)}{\partial y^n}\frac{y_1^n}{n!} & \sum\limits_{n=0}^{\infty}\frac{\partial^n f(x_p,0)}{\partial y^n}\frac{y_2^n}{n!} & \ldots & \sum\limits_{n=0}^{\infty}\frac{\partial^n f(x_p,0)}{\partial y^n}\frac{y_q^n}{n!}
# \end{pmatrix}$$
# We approximating this matrix with matrix X in such way, that every remainder $|a_{ij}-x_{ij}| \leq \epsilon$. So every element $x_{ij}$ should be equal to $\sum\limits_{n=0}^{\infty}\frac{\partial^n f(x_p,0)}{\partial y^n}\frac{y_1^n}{n!} + \epsilon_{ij}$, where $\epsilon_{ij}$ - remainder, which should be not bigger by modulus than $\epsilon$. Since Taylor remainder converges to zero when $n \to \infty$, we can show $x_{ij}$ as $x_{ij}=\sum\limits_{n=0}^{N}\frac{\partial^n f(x_p,0)}{\partial y^n}\frac{y_1^n}{n!} + \epsilon_{ij}$, where N big enough and $R(N)$ - Taylor remainder such $|R(N)-\epsilon_{ij}| \leq epsilon \to R(N)-\epsilon \leq \epsilon_{ij} \leq R(N)+\epsilon$. Thus if we want error $\epsilon_{ij}$ for $a_{ij}$ we need to take such $N_{ij}$ that error will be small.\
# Let's take maximum $N_{ij}$. Let's take such N for all $x_{ij}$ elements that $N\geq max(N_{ij})$ and $|R_{ij}(N)|\leq \epsilon$. Then X can be shown as:$$\begin{pmatrix}
# \sum\limits_{n=0}^{N}\frac{\partial^n f(x_1,0)}{\partial y^n}\frac{y_1^n}{n!}+\epsilon_{11} & \sum\limits_{n=0}^{N}\frac{\partial^n f(x_1,0)}{\partial y^n}\frac{y_2^n}{n!}+\epsilon_{12} & \ldots & \sum\limits_{n=0}^{N}\frac{\partial^n f(x_1,0)}{\partial y^n}\frac{y_q^n}{n!}+\epsilon_{1q}\\
# \ldots & \ldots\\
# \sum\limits_{n=0}^{N}\frac{\partial^n f(x_p,0)}{\partial y^n}\frac{y_1^n}{n!}+\epsilon_{p1} & \sum\limits_{n=0}^{N}\frac{\partial^n f(x_p,0)}{\partial y^n}\frac{y_2^n}{n!} +\epsilon_{p2}& \ldots & \sum\limits_{n=0}^{N}\frac{\partial^n f(x_p,0)}{\partial y^n}\frac{y_q^n}{n!}+\epsilon_{pq}
# \end{pmatrix} = \begin{pmatrix} \epsilon_{11} & \epsilon_{12} & \ldots & \epsilon_{1q}\\ \ldots & \ldots \\ \epsilon_{p1} & \epsilon_{p2} & \ldots & \epsilon_{pq} \end{pmatrix}+\sum\limits_{n=0}^{N}\frac{1}{n!}\begin{pmatrix}
# \frac{\partial^n f(x_1,0)}{\partial y^n}y_1^n & \frac{\partial^n f(x_1,0)}{\partial y^n}y_2^n & \ldots & \frac{\partial^n f(x_1,0)}{\partial y^n}y_q^n\\
# \ldots & \ldots\\
# \frac{\partial^n f(x_p,0)}{\partial y^n}y_1^n & \frac{\partial^n f(x_p,0)}{\partial y^n}y_2^n & \ldots & \frac{\partial^n f(x_p,0)}{\partial y^n}y_q^n
# \end{pmatrix}
# $$\
# Where last sum of matrix can pe represented as $$\sum\limits_{n=0}^{N}\frac{1}{n!}\begin{pmatrix}
# \frac{\partial^n f(x_1,0)}{\partial y^n}\\
# \ldots \\
# \frac{\partial^n f(x_p,0)}{\partial y^n}
# \end{pmatrix}\begin{pmatrix} y_1^n \ldots y_q^n
# \end{pmatrix}$$
# Now let's estimate $|R(N)|$:$$|R(N)| = |\sum\limits_{n=N+1}^{\infty}\frac{\partial^n f(x_i,0)}{\partial y^n}\frac{y_j^n}{n!}| \leq \sum\limits_{n=N+1}^{\infty}|\frac{\partial^n f(x_i,0)}{\partial y^n}|\frac{y_j^n}{n!} \leq \sum\limits_{n=N+1}^{\infty} M \frac{y_j^n}{n!} \leq M \sum\limits_{n=N+1}^{\infty}\frac{1}{n!}$$ since $y_j \leq 1$ $$\sum\limits_{n=N+1}^{\infty}\frac{1}{n!} = \frac{1}{(N+1)!}(1+\sum\limits_{n=2}^{\infty}\frac{1}{\prod_{k=2}^n(N+k)}) \leq \frac{1}{(N+1)!}\sum\limits_{n=0}^{\infty}(\frac{1}{N+2})^n = \frac{1}{(N+1)!}\frac{N+2}{N+1} \leq \frac{2}{(N+1)!}$$
# And since $|R(N)| \leq \epsilon$ let's take such N that $\frac{2M}{(N+1)!} \leq \epsilon \to (N+1)! \geq \frac{2M}{\epsilon}$. Let's use upper bound on n!: $n! \leq \frac{n^{n+1}}{e^{n-1}}$. Thus $$\frac{2M}{\epsilon} \leq (N+1)! \leq \frac{(N+1)^{N+2}}{e^{N}} \leq (N+1)^{N+2} \to \ln(\frac{2M}{\epsilon}) \leq (N+2)\ln(N+1) \leq (N+2)^2 \to \sqrt{\ln(\frac{2M}{\epsilon})}-2 \leq N$$
# Thus we can take $N = \sqrt{\ln(\frac{2M}{\epsilon})}$ and it will lead to $|A-X|_{\infty}\leq \epsilon$. So X can be expressed as sum of $\sqrt{\ln(\frac{2M}{\epsilon})}$ matricies with rank 1, which means that $\epsilon$ rank bounded with $\sqrt{\ln(\frac{2M}{\epsilon})}$ this bound doesn't depend on p,q and choice of points.
# + (6 pts). Extend result from the previous point (a.) to $x, y \in \mathbb{R}^{N}$. Observe how the bound depends on $N$.
#
# In previous section we used such properties that all derivatives bounded at points $(x,0)$ and every number $(y-0)^n$ bounded with some number, more specifically with 1. So for extending results on $R^N$ we need more conditions or limitations.
#
# Firstly, we can just bound domain of definition for $y$ by some area, for example $[-L,L]^N$, and secondly, limit all derivatives $|\frac{\partial^n f(x_1,x_2\ldots,x_N,0,\ldots,0)}{\partial y_1^{\alpha_1}\ldots \partial y_N^{\alpha_N}}| < M$ where $\sum \alpha_i = n$.\
# In this situation we have bound on remainder:
# $$|R(K)| = |\sum\limits_{n=K+1}^{\infty}\sum\limits_{\sum\alpha_i=n}\frac{\partial^n f(x_{1i},\ldots,x_{Ni},0,\ldots,0)}{\partial y_1^{\alpha_1}\ldots \partial y_N^{\alpha_N}}\frac{y_{1j}^{\alpha_1}y_{2j}^{\alpha_2}\ldots y_{Nj}^{\alpha_N}}{n!}| \leq \sum\limits_{n=K+1}^{\infty}\frac{N^n M L^n}{n!} \leq \frac{M*(NL)^{K+1}}{(K+1)!}(1+\sum\limits_{n=2}^{\infty}\frac{(NL)^{n-1}}{\prod_{k=2}^n(K+k)}) \leq \frac{2M*(NL)^{K+1}}{(K+1)!}\leq \epsilon$$
# Last two inequalities holds due to proven above and assumption that we take such big K that $NL/(K+2) < 1$. First holds due to modulus unequation and fact that sum of multinomial coefficients equal to $N^n$, where N - num of elements in sum and n - power of sum. Now:
# $$\frac{(NL)^{K+1}}{(K+1)!}\leq \frac{\epsilon}{2M} \to \frac{2M}{\epsilon} \leq \frac{(K+1)!}{(NL)^{K+1}} \leq (\frac{K+1}{NL})^{K+1} \to \ln(\frac{2M}{\epsilon}) \leq (K+1)\frac{K+1}{NL} \to \sqrt{NL\ln(\frac{2M}{\epsilon})}\leq K+1$$
# Thus, epsilon rank of matrix A bounded with $\sqrt{NL\ln(\frac{2M}{\epsilon})}-1$. Also, we can extend result on every compact set in $R^N$, and thus L - it's a radius of sphere, which contains whole given domain of definition of function.
#
# + (3 pts). Demonstarate your bounds from two previous points numerically on functions
#
#     + (1 pts). $\cos(xy)$, $\exp(-(x-y)^2)$ and a few on your choice for $N=1$
#     + (1 pts). [RBF kernel](https://scikit-learn.org/stable/modules/gaussian_process.html#radial-basis-function-rbf-kernel) for different $N$.
#     + (1 pts). [Exp-Sine-Squared kernel](https://scikit-learn.org/stable/modules/gaussian_process.html#exp-sine-squared-kernel) for different $N$.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from collections import defaultdict
import jax.numpy as jnp
import numpy as np

# %% [markdown]
# Let's take an upper bound of epsilon rank A as NL*ln(2M/eps)

# %% [markdown]
# Matrix sizes:

# %%
p1,q1 = 20, 30
p2,q2 = 50, 120
p3,q3 = 230, 200
p4, q4 = 500, 600

# %% [markdown]
# Cosine function, where x,y in [0,1]. M = 1.

# %%
x1, y1 = np.random.uniform(size=p1), np.random.uniform(size=q1)
x2, y2 = np.random.uniform(size=p2), np.random.uniform(size=q2)
x3, y3 = np.random.uniform(size=p3), np.random.uniform(size=q3)
x4, y4 = np.random.uniform(size=p4), np.random.uniform(size=q4)

# %%
L = 1
cos1 = np.array([[np.cos(i*j)  for j in y1] for i in x1])
cos2 = np.array([[np.cos(i*j)  for j in y2] for i in x2])
cos3 = np.array([[np.cos(i*j)  for j in y3] for i in x3])
cos4 = np.array([[np.cos(i*j)  for j in y4] for i in x4])
eps = 0.1
M = L
print("upper bound = ",L*np.log(2*M/eps))
# Out:
# upper bound =  2.995732273553991

# %%
for A in [cos1,cos2,cos3,cos4]:
  U,S,V = np.linalg.svd(A, full_matrices=False)
  S = S / max(S)
  S[S <= eps] = 0
  print(np.count_nonzero(S))
# Out:
# 1
# 1
# 1
# 1

# %% [markdown]
# Exponent:

# %%
L = 10
x1, y1 = np.random.uniform(low=-L, high=L, size=p1), np.random.uniform(low=-L, high=L,size=q1)
x2, y2 = np.random.uniform(low=-L, high=L, size=p2), np.random.uniform(low=-L, high=L, size=q2)
x3, y3 = np.random.uniform(low=-L, high=L, size=p3), np.random.uniform(low=-L, high=L, size=q3)
x4, y4 = np.random.uniform(low=-L, high=L, size=p4), np.random.uniform(low=-L, high=L, size=q4)

# %%
exp1 = np.array([[np.exp(-(i-j)**2)  for j in y1] for i in x1])
exp2 = np.array([[np.exp(-(i-j)**2)  for j in y2] for i in x2])
exp3 = np.array([[np.exp(-(i-j)**2)  for j in y3] for i in x3])
exp4 = np.array([[np.exp(-(i-j)**2)  for j in y4] for i in x4])
eps = 0.5

# %%
for A in [exp1,exp2,exp3, exp4]:
  U,S,V = np.linalg.svd(A, full_matrices=False)
  S = S / max(S)
  S[S <= eps] = 0
  print(np.count_nonzero(S))
# Out:
# 6
# 7
# 9
# 10

# %% [markdown]
# f(x,y) = (x+y)^2. M = 4*L, where L - size of definition domain.

# %%
L = 20
x1, y1 = np.random.uniform(low=-L, high=L, size=p1), np.random.uniform(low=-L, high=L,size=q1)
x2, y2 = np.random.uniform(low=-L, high=L, size=p2), np.random.uniform(low=-L, high=L, size=q2)
x3, y3 = np.random.uniform(low=-L, high=L, size=p3), np.random.uniform(low=-L, high=L, size=q3)
x4, y4 = np.random.uniform(low=-L, high=L, size=p4), np.random.uniform(low=-L, high=L, size=q4)
f1 = np.array([[(i+j)**2  for j in y1] for i in x1])
f2 = np.array([[(i+j)**2  for j in y2] for i in x2])
f3 = np.array([[(i+j)**2  for j in y3] for i in x3])
f4 = np.array([[(i+j)**2  for j in y4] for i in x4])
eps = 0.5
M = 4*L
print("upper bound = ",L*np.log(2*M/eps))
for A in [f1,f2,f3,f4]:
  U,S,V = np.linalg.svd(A, full_matrices=False)
  S = S / max(S)
  S[S <= eps] = 0
  print(np.count_nonzero(S))
# Out:
# upper bound =  115.36641991587544
# 2
# 2
# 2
# 2

# %% [markdown]
# RBF Kernel with L = 20 definition domain. M = pi

# %%
N1 = 5
N2 = 10
N3 = 15
L = 20
l = 2
eps = 0.1

x1, y1 = np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(p1)]), np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(q1)])
x2, y2 = np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(p2)]), np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(q2)])
x3, y3 = np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(p3)]), np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(q3)])
x4, y4 = np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(p4)]), np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(q4)])
f1 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y1] for i in x1])
f2 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y2] for i in x2])
f3 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y3] for i in x3])
f4 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y4] for i in x4])

print("upper bound for N = 5: ",N1*L*np.log(2*M/eps))
for A in [f1,f2,f3,f4]:
  U,S,V = np.linalg.svd(A, full_matrices=False)
  S = S / max(S)
  S[S <= eps] = 0
  print(np.count_nonzero(S))
    
x1, y1 = np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(p1)]), np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(q1)])
x2, y2 = np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(p2)]), np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(q2)])
x3, y3 = np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(p3)]), np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(q3)])
x4, y4 = np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(p4)]), np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(q4)])
f1 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y1] for i in x1])
f2 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y2] for i in x2])
f3 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y3] for i in x3])
f4 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y4] for i in x4])
print("upper bound for N = 10: ",N2*L*np.log(2*M/eps))
for A in [f1,f2,f3,f4]:
  U,S,V = np.linalg.svd(A, full_matrices=False)
  S = S / max(S)
  S[S <= eps] = 0
  print(np.count_nonzero(S))

x1, y1 = np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(p1)]), np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(q1)])
x2, y2 = np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(p2)]), np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(q2)])
x3, y3 = np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(p3)]), np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(q3)])
x4, y4 = np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(p4)]), np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(q4)])
f1 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y1] for i in x1])
f2 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y2] for i in x2])
f3 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y3] for i in x3])
f4 = np.array([[np.exp(-np.sum((i-j)**2)/(2*l**2))  for j in y4] for i in x4])
print("upper bound for N = 15: ",N3*L*np.log(2*M/eps))
for A in [f1,f2,f3,f4]:
  U,S,V = np.linalg.svd(A, full_matrices=False)
  S = S / max(S)
  S[S <= eps] = 0
  print(np.count_nonzero(S))
# Out:
# upper bound for N = 5:  737.7758908227872
# 1
# 3
# 9
# 31

# %% [markdown]
# Exp-sine squared kernel with L = 15 definition domain. M = pi.

# %%
N1 = 3
N2 = 11
N3 = 19
L = 15
l = 2
p = 3
x1, y1 = np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(p1)]), np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(q1)])
x2, y2 = np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(p2)]), np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(q2)])
x3, y3 = np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(p3)]), np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(q3)])
x4, y4 = np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(p4)]), np.asarray([np.random.uniform(low=-L, high=L, size=N1) for i in range(q4)])
f1 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2)  for j in y1] for i in x1])
f2 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2)  for j in y2] for i in x2])
f3 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2)  for j in y3] for i in x3])
f4 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2) for j in y4] for i in x4])
eps = 0.05
print("upper bound for N = 3: ",N1*L*np.log(2*M/eps))
for A in [f1,f2,f3,f4]:
  U,S,V = np.linalg.svd(A, full_matrices=False)
  S = S / max(S)
  S[S <= eps] = 0
  print(np.count_nonzero(S))
    
x1, y1 = np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(p1)]), np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(q1)])
x2, y2 = np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(p2)]), np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(q2)])
x3, y3 = np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(p3)]), np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(q3)])
x4, y4 = np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(p4)]), np.asarray([np.random.uniform(low=-L, high=L, size=N2) for i in range(q4)])
f1 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2) for j in y1] for i in x1])
f2 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2) for j in y2] for i in x2])
f3 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2)  for j in y3] for i in x3])
f4 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2)  for j in y4] for i in x4])
print("upper bound for N = 11: ",N2*L*np.log(2*M/eps))
for A in [f1,f2,f3,f4]:
  U,S,V = np.linalg.svd(A, full_matrices=False)
  S = S / max(S)
  S[S <= eps] = 0
  print(np.count_nonzero(S))

x1, y1 = np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(p1)]), np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(q1)])
x2, y2 = np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(p2)]), np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(q2)])
x3, y3 = np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(p3)]), np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(q3)])
x4, y4 = np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(p4)]), np.asarray([np.random.uniform(low=-L, high=L, size=N3) for i in range(q4)])
f1 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2) for j in y1] for i in x1])
f2 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2) for j in y2] for i in x2])
f3 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2) for j in y3] for i in x3])
f4 = np.array([[np.exp(-2*np.sin((np.pi*np.sum((i-j)**2)/p))**2/l**2) for j in y4] for i in x4])
print("upper bound for N = 19: ",N3*L*np.log(2*M/eps))
for A in [f1,f2,f3,f4]:
  U,S,V = np.linalg.svd(A, full_matrices=False)
  S = S / max(S)
  S[S <= eps] = 0
  print(np.count_nonzero(S))

# %% [markdown]
# # Problem 3 (Molecules) (16 pts)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from collections import defaultdict
import jax.numpy as jnp
import numpy as np

# %% [markdown]
# We have in our posession a database with molecules. Each molecule has five atoms `A`, `B`, `C`, `D`, `E` located in the same plane $x, y$.
#
# The coordinates of the molecules was collected by an automatic system that processed "pictures" from the electronic microscope. As a result, some of the samples differs by unkonwn rotation in $2D$ space. Your task is to normalize this database to find distinct molecules.

# %%
data = pd.read_csv("https://raw.githubusercontent.com/oseledets/nla2022/main/hw1/molecules.csv", index_col=0)
data.head()
# Out:
#         A_x  A_y       B_x       B_y       C_x       C_y       D_x       D_y  \
# sample
# 0       0.0  0.0 -0.568099 -0.822960  0.411480 -0.284050 -0.983627 -0.180214
# 1       0.0  0.0 -0.816462  0.577399  0.288700  0.408231 -0.169043  0.985609
# 2       0.0  0.0 -0.999628 -0.027283  0.013642 -0.499814 -0.726136  0.687551
# 3       0.0  0.0  0.946140  0.323758 -0.161879  0.473070 -0.897953  0.440091
# 4       0.0  0.0 -0.901767  0.432222 -0.216111 -0.450884  0.332018 -0.943273
#
#              E_x       E_y
# sample
# 0      -0.180214  0.983627
# 1       0.169043 -0.985609
# 2       0.687551  0.726136
# 3      -0.440091 -0.897953
# 4       0.943273  0.332018

# %%
molecules = data.to_numpy().reshape(len(data), 5, 2)
molecules.shape
# Out:
# (500, 5, 2)

# %%
def draw_molecule(ax, molecule):
    ax.scatter(*molecule.T, color="black", s=50)
    for i in range(1, molecule.shape[0]):
        ax.plot(*molecule[[0, i], :].T, color="black")
    ax.axis("off")
    ax.axis("equal")

# %%
k = 5
fig, ax = plt.subplots(k, k, figsize=(2*k, 2*k))
ax = ax.reshape(-1,)
for i in range(k**2):
    draw_molecule(ax[i], molecules[i])

# %% [markdown]
# ## What you should do:
#
# + (2 pts). Prove that orthogonal transformations preserve $l_2$ norm, i.e., $\left\|x\right\|_2 = \left\|Ux\right\|_2$, where $U$ is an orthogonal matrix.

# %% [markdown]
# Let's check: $\|Ux\|_2=\sqrt{(Ux)^TUx}=\sqrt{x^TU^TUx}=\sqrt{x^Tx}=\|x\|_2$ for vectors.\
# For matricies: $\|Ux\|_2=\|UU^{'}\Sigma (V^{'})^T\|_2 = \sigma_1(\Sigma)=\sigma_1(x)$, where $UU^{'}$ - unitary matrix.
# Thus, $U$ preserves $l_2$ norm.

# %% [markdown]
# + (4 pts). Use the result from the previous point to construct an algorithm that distinguishes different molecules. Implement it and run on the database. Produce a list of distinct molecules and visualise them.

# %%
def find_similar_molecules(molecules):
    bc = molecules[:,1,:] - molecules[:,2,:]
    cd = molecules[:,2,:] - molecules[:,3,:]
    de = molecules[:,3,:] - molecules[:,4,:]
    eb = molecules[:,4,:] - molecules[:,1,:]
    vecs = np.stack((bc,cd,de, eb),axis=1)
    norms = np.round(np.linalg.norm(vecs, axis=2), 6)
    classes = defaultdict(list)
    for i,v in enumerate(norms):
        classes[tuple(v)].append(molecules[i])
    return classes

# %%
classes = find_similar_molecules(molecules)
keys = list(classes.keys())
types = [classes[keys[i]][0] for i in range(len(keys))]

# %%
k = 3
fig, ax = plt.subplots(1, k, figsize=(10, 5))
fig.suptitle('Different molecules', fontsize=16)
ax = ax.reshape(-1,)
for i in range(k):
    draw_molecule(ax[i], types[i])

# %%
k = 49
fig, ax = plt.subplots(7, 7, figsize=(15, 15))
fig.suptitle('1st type', fontsize=20)
ax = ax.reshape(-1,)
molecule1 = classes[keys[0]]
for i in range(k):
    draw_molecule(ax[i], molecule1[i])

# %%
k = 49
fig, ax = plt.subplots(7, 7, figsize=(15, 15))
fig.suptitle('2nd type', fontsize=20)
ax = ax.reshape(-1,)
molecule2 = classes[keys[1]]
for i in range(k):
    draw_molecule(ax[i], molecule2[i])

# %%
k = 49
fig, ax = plt.subplots(7, 7, figsize=(15, 15))
fig.suptitle('3rd type', fontsize=20)
ax = ax.reshape(-1,)
molecule3 = classes[keys[2]]
for i in range(k):
    draw_molecule(ax[i], molecule3[i])

# %% [markdown]
# + (7 pts). Learn about [Kabsch algorithm](https://en.wikipedia.org/wiki/Kabsch_algorithm). Implement it and run on the database. Produce a list of distinct molecules and visualise them.

# %%
def kabsch_algo(molecule1, molecule2):
    h = jnp.matmul(molecule1.T, molecule2)
    u,s,vt = jnp.linalg.svd(h)
    d = jnp.linalg.det(jnp.matmul(vt.T, u.T))
    e = jnp.array([[1,0],[0,d]])
    r = jnp.matmul(jnp.matmul(vt.T, e), u.T)
    return r

# %%
def clasterize(molecules):
    key = False
    classes = defaultdict(list)
    j = -1
    for i in molecules:
        for j,v in classes.items():
            r = kabsch_algo(i, v[0])
            if not np.round(jnp.linalg.norm(i-v[0]@r),5):
                classes[j].append(i)
                key = True
                break
        if not key:
            classes[j+1].append(i)
        key = False
    return classes

# %%
kabsch_classes = clasterize(molecules)

# %%
k = 5
fig, ax = plt.subplots(1, 5, figsize=(10, 5))
fig.suptitle('Different molecules', fontsize=16)
ax = ax.reshape(-1,)
for i in range(k):
    draw_molecule(ax[i], kabsch_classes[i][0])

# %%
k = 49
fig, ax = plt.subplots(7, 7, figsize=(15, 15))
fig.suptitle('1st type', fontsize=20)
ax = ax.reshape(-1,)
for i in range(k):
    draw_molecule(ax[i], kabsch_classes[0][i])

# %%
k = 49
fig, ax = plt.subplots(7, 7, figsize=(15, 15))
fig.suptitle('2nd type', fontsize=20)
ax = ax.reshape(-1,)
for i in range(k):
    draw_molecule(ax[i], kabsch_classes[1][i])

# %%
k = 49
fig, ax = plt.subplots(7, 7, figsize=(15, 15))
fig.suptitle('3rd type', fontsize=20)
ax = ax.reshape(-1,)
for i in range(k):
    draw_molecule(ax[i], kabsch_classes[2][i])

# %%
k = 49
fig, ax = plt.subplots(7, 7, figsize=(15, 15))
fig.suptitle('4th type', fontsize=20)
ax = ax.reshape(-1,)
for i in range(k):
    draw_molecule(ax[i], kabsch_classes[3][i])

# %%
k = 49
fig, ax = plt.subplots(7, 7, figsize=(15, 15))
fig.suptitle('5th type', fontsize=20)
ax = ax.reshape(-1,)
for i in range(k):
    draw_molecule(ax[i], kabsch_classes[4][i])

# %% [markdown]
# + (3 pts). Compare results of algorithm from 2. and from 3. Explain the difference.

# %%
print(len(classes))
print(len(kabsch_classes))
# Out:
# 3
# 5

# %% [markdown]
# As we can see, simple algorithm detected only 3 different molecules while kabsch algorithm distinguished 5. It happened because my algorithm hadn't detected mirrored molecules cause it lookes only on distances between atoms.

# %% [markdown]
# # Problem 4 (Disentangled representation) (12 pts)

# %% [markdown]
# ## Brief intro

# %% [markdown]
# The main component of [GAN](https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html) is Generator network. Generator is such model that takes as input random vector and produces an image. In this task, we will work with the already pre-trained generator $G$. Here are a few things you need to know about this model:
#
#
#
# 1.   **Model input:** batch of random vectors $z\sim N(0,1)$ with normally distributed values of size **(Batch_Size,100)**. Here, Batch_Size is a number of images we want to generate
# 2.   **Model output:** $\mathrm{images} = G(z)$ - batch of images with size **(Batch_Size,3,64,64)**. Here **3** - defines number of image channels (3 for RGB images), **64, 64** - width and height.
# 3.   **Model structure:** generator is a set of sequentially appplied functions. Each function input is the output of the previous one. In other words, $G(z) = f_N(f_{N-1}...f_1(f_0(z)))$. $N$ - defines number of functions in generator.

# %% [markdown]
# ### Disentanglement

# %% [markdown]
# The good property of GAN is that generator input space has a set of meaningful directions - moving input vector along this directions produce interpretable changes in image. For example, we can change a Pose, Age, Expression or even add eyeglasses. You can read more about it on [resource](https://genforce.github.io/interfacegan/). The main question is how to find such good directions. This problem is called disentanglement.

# %% [markdown]
# ![](https://github.com/genforce/interfacegan/blob/master/docs/assets/teaser.jpg?raw=true)

# %% [markdown]
# ## Problem discription

# %% [markdown]
# We are going to find meaningful directions using SVD applied over the Jacobian matrix of some hidden output with respect to model input. **i-th** hidden output of generator model is defined by formula $G_{i}(z) = f_i(f_{i-1}...f_1(f_0(z))))$, where $i < N$. So, the task could be splitted on four main parts:
#
# 1. **(4 pts)**   Write the function **Get_Hidden_Output**, which reproduces formula $G_{i}(z) = f_i(f_{i-1}...f_1(f_0(z))))$
# 2. **(3 pts)**   Calculate jacobian matrix $J$ of generator $G$ for several **i** values. For each of them:
#
# *   Calculate the jacobian matrix with respect to $z$: $\frac{\partial G(z)}{\partial z}$
# *   Reshape jacobian matrix to have the size **(Batch_Size * Hidden_Output_Size,100)**
#
# 3. **(3 pts)**  Apply SVD to jacobian matrix ($J = U @ S @ V.T$) from previous step
#
# 4. **(2 pts)**  Take several directions from matrix $V$ (particular columns), and run visualization code (already written for you). Leave a comment on what you got (how found directions affect image)
#
# **Attention!!!**
#
# 1.  Please run the code on google colab to fulfil packages requirements
# 2.  Jacobian matrix computation may take more than 20 minutes!
# 3.  Use GPU runtime to accelerate computations

# %% [markdown]
# ## Prerequisites

# %%
# !pip3 install functorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
from torch import nn
import requests
import matplotlib.pyplot as plt
import numpy as np
from torchvision import utils as vutils
from torchvision import transforms
from tqdm import tqdm
from google.colab import files
from functorch import vmap, jacfwd, jacrev
from functorch.experimental import replace_all_batch_norm_modules_
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /usr/local/lib/python3.7/dist-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
#   hidden generator size
ngf = 64

# Number of channels in the training images. For color images this is 3
nc = 3

# Size of z latent vector (i.e. size of generator input)
nz = 100

print(f"Device: {device}, latent size {nz}, generator hidden dim {ngf}, number of image channels {nc}")
# Out:
# Device: cuda:0, latent size 100, generator hidden dim 64, number of image channels 3

# %%
def download_file_from_google_drive(id, destination):
    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

# %%
class Generator(nn.Module):
    def __init__(self, ngpu):
        super(Generator, self).__init__()
        self.ngpu = ngpu
        self.main = nn.Sequential(
            # input is Z, going into a convolution
            nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # state size. (ngf*2) x 16 x 16
            nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size. (nc) x 64 x 64
        )
    def get_function_output(self, inp, index=0):
      if index == 0:
        inp = inp[:,:,None,None]
      return self.main[index](inp)
    def get_number_of_layers(self):
      return len(self.main)

    def forward(self, input):
        return self.main(input[:,:,None,None])

# %%
file_id = "1hIh2-8KjcUku1Dl-mLYqEObbODrCW_Fp"
destination = './G_checkpoint.pt'
download_file_from_google_drive(file_id, destination)
G = Generator(1).to(device)
G.load_state_dict(torch.load('./G_checkpoint.pt', map_location="cpu"))
replace_all_batch_norm_modules_(G)
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (11): ReLU(inplace=True)
# ...

# %%
def sample_batch(batch_size):
  return torch.randn((batch_size,nz),device=device)

# %%
def ToPILImage(tensor):
  return transforms.ToPILImage()(tensor)

# %%
def ConvertTensorsToOne(tensor, nrow=None):
  if nrow is None:
    nrow = int(tensor.size(0) ** 0.5)
  return vutils.make_grid(tensor, padding=2, normalize=True, nrow=nrow).cpu()

# %% [markdown]
# ## Generator network visualization

# %%
# generator model consist of 14 functions numbered from 0 to 13

G
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (11): ReLU(inplace=True)
# ...

# %%
# sample 64 random vectors to produce 64 images

z = sample_batch(64)

z.shape
# Out:
# torch.Size([64, 100])

# %%
# producing images

out = G(z)

out.shape
# Out:
# torch.Size([64, 3, 64, 64])

# %%
# generate hidden output for given input (remember that functions are applied sequentially - input should be the output of previous function)
# index defines which function output will be returned
# for function with index 0 input will be model input "z"

hidden_output = G.get_function_output(z,index=0)

hidden_output.shape
# Out:
# torch.Size([64, 512, 4, 4])

# %%
# plotting the images by combining them into one, with 8 images in each row (nrow=8)

plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Generator output")
plt.imshow(ToPILImage(ConvertTensorsToOne(out, nrow=8)))

# %% [markdown]
# ## Perform experiments

# %% [markdown]
# **Define the function that returns the output of any generator function for given input z and generator function index (4 pts)**

# %%
def Get_Hidden_Output(z,index):
  out = G.get_function_output(z)
  for i in range(index):
      out = G.get_function_output(out, i+1)
  return out

# %% [markdown]
# **Define the function that calculates the jacobian matrix based on given input z and generator function index (use the function which you implemented earlier) (3 pts)**

# %%
def Calc_Gradient(z, index):
  grads = vmap(jacfwd(lambda z: Get_Hidden_Output(z, index=index)))(z.unsqueeze(1))
  return grads

# %%
index = 3
z = sample_batch(20)
grads3 = Calc_Gradient(z,index)
grads7 = Calc_Gradient(z,index+4)
grads11 = Calc_Gradient(z,index+7)

# %% [markdown]
# **Calculate SVD and visualize singular values for several generator function indexes (2-3 indexes are enough). Based on singular value plots, decide what generator function is more useful for disentangled representation search and why, leave a comment.(3 pts)**

# %%
grads = [grads3, grads7, grads11]
plt.figure(figsize=(10,10))
for i,v in enumerate([3,7,11]):
  U, S, V = torch.linalg.svd(grads[i].reshape(-1,nz), full_matrices=False)
  plt.plot(S.cpu().detach().numpy(),label=v)

plt.legend()

# %%
plt.figure(figsize=(10,10))
for i,v in enumerate([3,7,11]):
  U, S, V = torch.linalg.svd(grads[i].reshape(-1,nz), full_matrices=False)
  plt.plot((S/S[0]).cpu().detach().numpy(),label=v)
plt.legend()

# %% [markdown]
# As we can see, output of 11th function has bigger singular values and they decrease a little bit faster, so it's better to take this function for disentanglend search. It's because when singular values decrease faster, more unnecessary information layer forget and preserves only important. Moreover, the more difference between singular values, more information difference in corresponding vectors, so vectors will responsible for different features. And of course, bigger singular values - more information corresponing vectors hold.

# %% [markdown]
# **Choose some directions from matrix V (some columns) corresponding to chosen generator function index (based on previous step). Run visualization code. Which image attributes affects chosen directions? (2 pts)**

# %%
U, S, V = torch.linalg.svd(Calc_Gradient(z, 11).reshape(-1,nz), full_matrices=False)

# %%
def make_edit(input, dirs):
  output = G(input)
  input_shift = input[:,None,:] + dirs[None,:,:]*3
  output_shift = G(input_shift.reshape(-1,nz)).reshape(input.size(0),-1,3,64,64)
  return torch.cat([output[:,None],output_shift],dim=1).reshape(-1,3,64,64)

# %%
input = sample_batch(4)
dirs = torch.index_select(V,0,torch.tensor([0,2,5,10]).to(device))# your solution, number of directions should be the first dimension

# %%
out = make_edit(input, dirs)
plt.figure(figsize=(16,16))
plt.axis("off")
plt.imshow(ToPILImage(ConvertTensorsToOne(out, nrow=(dirs.size(0)+1))))

# %% [markdown]
# As we can see on images, they differ in each row. And differences are in gender (somewhere there are man, in other columns there are women). Also there are some differences in face. For examples, columns 2 and 4.  Moreover, second column differs from others because of rotation, faces in this column turned in different way. And we can see some changes in hair.
